# %% [markdown]
# <a href="https://colab.research.google.com/github/Showmaker821/115-1/blob/main/411414923_H1_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello\nhello")
# Out:
# hello
# hello

# %%
a=1
b=2.5
c="piyan"
print(type(c))
# Out:
# <class 'str'>

# %%
x=100
y=87
temp=x
x=y
y=temp
print(x,y)
# Out:
# 87 100

# %%
F=5
K=87
print(id(K))
# Out:
# 10449160

# %%
X=50000
y=0.015
z=5
result=x*(1+y)**z
print(result)
# Out:
# 93.72370833794058
